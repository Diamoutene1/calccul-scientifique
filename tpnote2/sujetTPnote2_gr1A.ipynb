         4.67321739e+00, -3.79100000e+00, -2.59475682e-01,
         3.79846932e+00,  1.69784616e+00,  1.02320948e+01,
         9.69941177e+00,  5.72504335e+00,  2.60609795e+01]])

# %% [markdown]
# <hr/>
# 1.  Calculer le tableau tm qui contient les 15 valeurs moyennes des 10 séries (sans boucle).

# %%
# à compléter
moyenne=np.mean(mesures,axis=0)
print(moyenne)
# Out:
# [-1.68379808e-01  3.57966308e-01  2.51757460e-01 -7.29613459e-02
#  -7.56833698e-01  1.23930947e+00  2.35770784e+00  1.57930000e+00
#  -9.68485090e-03  3.51046495e-01 -3.56829640e-01  2.30579901e+00
#   3.54906659e+00  1.03219146e+01  9.82858945e+00]

# %% [markdown]
# <hr/>
# 2. Calculer le tableau des écarts entre les mesures et les moyennes par colonnes.
#
# En déduire combien de mesures sont plus grandes et combien sont plus petrites que la moyenne

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_26490/1956324730.py in <module>
#       1 # à compléter
# ----> 2 sup=np.sup(moyenne)
#
# /usr/lib/python3/dist-packages/numpy/__init__.py in __getattr__(attr)
#     311                 return Tester
#     312
# --> 313             raise AttributeError("module {!r} has no attribute "
#     314                                  "{!r}".format(__name__, attr))
#     315
#
# AttributeError: module 'numpy' has no attribute 'sup'

# %% [markdown]
# <hr/>
# 3.  Faire un graphique comme sur la figure ci-dessous: ce shéma doit comporter les points correspondants à x en abscisse et pour les ordonnées à<br/>
# - au premier sous-tableau <br/>
# - au dernier sous-tableau <br/>
# - au tableau des moyennes <br/>

# %%
# à compléter
moyennes = np.mean(mesures, axis=0)


# Tracer le tableau des moyennes
plt.plot(moyennes, label='Moyennes')

# dernier sous tableau

plt.plot(mesures)
# premier sous tableau
plt.plot(x)

# Ajouter une légende
plt.legend()

# Ajouter un titre et des labels d'axe

plt.xlabel('Index')
plt.ylabel('Valeurs')

# Afficher le graphique
plt.grid(True)
plt.show()

# %% [markdown]
# <hr/>
# 4. On cherche à avoir une fonction dont la représentation graphique doit se rapprocher du dessin des moyennes.
#
# On hésite entre deux fonctions:
#
# Soit $f_1$ de la forme $ax^4+bx^3+cx^2+dx+e$
#
# Soit $f_2$ de la forme $exp (a_1x^3+b_1x)$
#
# Utilisez la fonction `scipy.optimize.curve_fit` pour déterminer les paramaètres de ces deux fonctions.

# %%
import scipy.optimize

# à compléter
def polynomial_func(t, a, b, c, d,e):
    return a*t**4+b*t**3+c*t**2+d*t+e


params = scipy.optimize.curve_fit(polynomial_func,mesures )

# Les paramètres ajustés
a_fit, b_fit, c_fit, d_fit,e_fit = params
print("Paramètres ajustés (a, b, c, d,e) :", a_fit, b_fit, c_fit, d_fit)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26490/1825317822.py in <module>
#       6
#       7
# ----> 8 params = scipy.optimize.curve_fit(polynomial_func,mesures )
#       9
#      10 # Les paramètres ajustés
#
# TypeError: curve_fit() missing 1 required positional argument: 'ydata'

# %% [markdown]
# <hr/>
# 5. On veut évaluer ces deux fonctions trouvées. Calculer et afficher les résidus (écart entre modèle et données) au moyen de la formule $r=\frac{\sqrt{\sum(f(t)-t_i)^2}}{N}$.

# %%
# à compléter
# Out:
# résidu moyen avec les moyennes: 0.319163517376509
# résidu moyen avec les moyennes: 0.3688082047404798

# %% [markdown]
# <hr/>
# 6. Tracer sur la même courbe la moyenne des données relevées et les courbes obtenues à la question précédente.

# %%
# à compléter

# %% [markdown]
# <hr/>
# 7. On cherche à interpoler entre les points pour estimer les valeurs entre ces points.
#
# - Interpoler au moyen de `scipy.interpolate.CubicSpline`
#
# - Tracer la  courbe interpolée et les points sur le même graphique.
# - Tracer également la courbe obtenue avec la méthode d'ajustement de la première partie.

# %%
import scipy.interpolate

# à compléter

# %%
# à compléter

# %% [markdown]
# 8. Grace à ces estimations, déterminer des valeurs approchées de la valeur qui devrait être obtenue pour x=-0.5

# %%
# à compléter
# Out:
# avec f1 0.3300092176479173
# avec f2 0.2524051896837732
# avec le cubicSpline 0.2173570942975416
